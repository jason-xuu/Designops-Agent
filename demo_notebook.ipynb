# %% [markdown]
# # DesignOps Agent Demo Notebook
#
# Use this notebook to run and inspect both briefs.

# %%
# !python run_agent.py --brief residential

# %%
# !python run_agent.py --brief mixed_use
